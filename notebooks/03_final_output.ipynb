# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import os, sys

PROJ_ROOT = os.path.abspath(os.path.join(os.pardir))
sys.path.append(os.path.join(PROJ_ROOT, 'src'))
import analysis

# %%
surname = 'Doughty'   # Input a surname
gender  = 'F'         # Input a gender between M and F
hyphen  =  False      # Whether to include hyphenated first-names, False = exclude

# %%
df = analysis.run_analysis(surname, gender, remove='Yes', hyphen=hyphen)
# Out:
# Lastname in dictionary: DAO1TIY0 IY0

# %%
#### OPTIONS FOR TRENDS

# - 'GROWING BOOM'
# - 'RECENT BOOM'
# - 'CONTINUED DECLINE'
# - 'RECENT DECLINE'
# - 'STABILITY'
# - 'DECLINE STABILISING'
# - 'GROWTH STABILISING'
# - 'CURRENTLY STABLE'

# %%
trend = df[df['trend_profile'] == 'RECENT BOOM']
trend.head(20)
# Out:
#            Name  Surname   Rank  Predicted Rank   Count  Predicted Change  \
# 1622  CHARLOTTE  DOUGHTY    9.0             6.0  2674.0             315.0
# 5163     MARGOT  DOUGHTY  166.0           130.0   363.0              97.0
# 6576       ROSA  DOUGHTY  171.0           157.0   345.0              37.0
# 269       AIZAH  DOUGHTY  191.0           168.0   305.0              50.0
# 507       AMARA  DOUGHTY  214.0           193.0   255.0              39.0
# 6178   PRIMROSE  DOUGHTY  229.0           190.0   243.0              65.0
# 743     ANTONIA  DOUGHTY  242.0           221.0   223.0              28.0
# 5876       NORA  DOUGHTY  254.0           225.0   213.0              35.0
# 953      ATHENA  DOUGHTY  258.0           237.0   209.0              25.0
# 2768      FLORA  DOUGHTY  263.0           228.0   205.0              40.0
# 5884       NOVA  DOUGHTY  268.0           230.0   201.0              38.0
# 3080     HANIYA  DOUGHTY  269.0           218.0   200.0              59.0
# ...
