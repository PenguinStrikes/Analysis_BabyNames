# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import os, sys

PROJ_ROOT = os.path.abspath(os.path.join(os.pardir))
sys.path.append(os.path.join(PROJ_ROOT, 'src'))
import analysis

# %%
surname = 'Doughty'   # Input a surname
gender  = 'F'         # Input a gender between M and F
hyphen  =  False      # Whether to include hyphenated first-names, False = exclude

# %%
df = analysis.run_analysis(surname, gender, remove='Yes', hyphen=hyphen)
# Out:
# Lastname in dictionary: DAO1TIY0 IY0

# %%
#### OPTIONS FOR TRENDS

# - 'GROWING BOOM'
# - 'RECENT BOOM'
# - 'CONTINUED DECLINE'
# - 'RECENT DECLINE'
# - 'STABILITY'
# - 'DECLINE STABILISING'
# - 'GROWTH STABILISING'
# - 'CURRENTLY STABLE'

# %%
trend = df[df['trend_profile'] == 'RECENT BOOM']
trend.head(20)
# Out:
#             Name  Surname   Rank  Predicted Rank  Count  Predicted Change  \
# 672    ANASTASIA  DOUGHTY  143.0           134.0  379.0              23.0
# 5177        LYRA  DOUGHTY  153.0           129.0  359.0              61.0
# 345       ALAYNA  DOUGHTY  168.0           143.0  333.0              48.0
# 544        AMARA  DOUGHTY  175.0           157.0  320.0              25.0
# 1110        AYDA  DOUGHTY  186.0           158.0  291.0              53.0
# 4501       KIARA  DOUGHTY  209.0           186.0  253.0              34.0
# 1039     AURELIA  DOUGHTY  212.0           189.0  248.0              33.0
# 5231       MAEVE  DOUGHTY  217.0           205.0  244.0              13.0
# 1820  CLEMENTINE  DOUGHTY  260.0           225.0  202.0              26.0
# 1100        AYAH  DOUGHTY  279.0           250.0  188.0              19.0
# 1108        AYAT  DOUGHTY  286.0           253.0  185.0              20.0
# 6136        NOLA  DOUGHTY  298.0           260.0  174.0              25.0
# 2611    EMMELINE  DOUGHTY  302.0           241.0  172.0              38.0
# 8138      VIENNA  DOUGHTY  303.0           239.0  172.0              42.0
# 8244      WINTER  DOUGHTY  313.0           227.0  166.0              62.0
# 178      ADELINE  DOUGHTY  327.0           283.0  155.0              24.0
# 1134        AYRA  DOUGHTY  330.0           301.0  152.0              16.0
# 530         AMAL  DOUGHTY  339.0           303.0  146.0              18.0
# 4560       KLARA  DOUGHTY  346.0           296.0  139.0              32.0
# 7882    THEODORA  DOUGHTY  354.0           329.0  136.0              14.0
#
#      trend_profile  similarity_score    phonetics_space phonetics_source
# 672    RECENT BOOM             27.78  AE0NAH0STEY1ZHAH0             dict
# 5177   RECENT BOOM             44.44           LAY1RAH0             dict
# 345    RECENT BOOM             33.33        AA0LEY1NAH0             pred
# 544    RECENT BOOM             33.33        AA0MAA1RAH0             dict
# 1110   RECENT BOOM             33.33            EY1DAH0             pred
# 4501   RECENT BOOM             33.33        KIY0AA1RAH0             pred
# 1039   RECENT BOOM             40.00     AO0REH1LIY0AH0             pred
# 5231   RECENT BOOM             22.22           MAH0EH1V             dict
# 1820   RECENT BOOM             25.00    KLEH1MAH0NTAY2N             dict
# 1100   RECENT BOOM             22.22           EY1HHAH0             pred
# 1108   RECENT BOOM             11.11           EY1EY1TT             pred
# 6136   RECENT BOOM             33.33           NOW1LAH0             dict
# 2611   RECENT BOOM             23.08       EH1MAH0LAY2N             dict
# 8138   RECENT BOOM             25.00        VIY0EH1NAH0             dict
# 8244   RECENT BOOM             40.00          WIH1NTER0             dict
# 178    RECENT BOOM             30.77       AE1DAH0LAY2N             dict
# 1134   RECENT BOOM             33.33            EY1RAH0             pred
# 530    RECENT BOOM             11.11           AH0MAA1L             dict
# 4560   RECENT BOOM             40.00          KLAA1RAH0             pred
# 7882   RECENT BOOM             35.29   THIY2AH0DAO1RAH0             dict
